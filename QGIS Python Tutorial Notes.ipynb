# %%
import pandas as pd
import os
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
os.chdir(r"C:\Users\samwa\OneDrive - University of Canterbury\ENCN493 - Project")
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Data',
#  'Journal Articles',
#  'QGIS Python Tutorial Notes.ipynb',
#  'Things to Learn.txt']

# %%
file = open('Things to Learn.txt', 'r+')
for i in file:
    print(i)
file.close()
# Out:
# Additionally, there are some things you should refresh if you have time/the inclination.
#
# Programming: know Python. Specifically, the packages pandas, geopandas, matplotlib.
#
# Geospatial analysis: do a tutorial on QGIS. Know what a shapefile is. Know how to plot a shapefile in python.
#
# Statistical analysis: understand bootstrapping and monte carlo. (notes are here: https://drive.google.com/open?id=1VW28CetzMgJGjKVp_LAC64Hk-GEDPx_i)
#
# Risk: be prepared to learn your understanding of risk from scratch.

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Data',
#  'Journal Articles',
#  'QGIS Python Tutorial Notes.ipynb',
#  'Things to Learn.txt']

# %%
os.chdir("Data")

# %%
os.listdir()
# Out:
# ['bikeways.dbf',
#  'bikeways.prj',
#  'bikeways.shp',
#  'bikeways.shx',
#  'city.dbf',
#  'city.prj',
#  'city.shp',
#  'city.shx',
#  'parks.dbf',
#  'parks.prj',
#  'parks.shp',
#  'parks.shx',
#  '_DS_Store']

# %%
data_file = gpd.read_file('bikeways.shp')

# %%
street_names = data_file['STREET_NAM']

# %%
final = ''
for i in street_names:
    final += i
print(final)
# Out:
# YukonBordenBoundary RdWylieOff Ramp Knight St BridgeW 33rd AveW 33rd AveE Kent Ave NorthE Kent Ave NorthE Kent Ave NorthE Kent Ave NorthE Kent Ave NorthW Kent Ave NorthW Kent Ave SouthSW Marine DriveHeatherHeatherHeatherDunbarDunbarDunbarOntarioRichardsRichardsRichardsRichardsSE Marine Dr to InvernessJones ParkVannessVannessBurrard MarinaWhyteWhyteLakewoodLakewoodTrout Lake ParkingCornishSW Marine DriveSW Marine DriveSW Marine DriveMemorial South parkBoundary RdOff VannessQuesnel DriveW 20th aveE 45th AveTrout LakeE 29th AveOff VannessFraser river walkwayHastings ParkStanley Park trailsStanley Park trailsBurrardBurrardBurrardHornbyHornbyCambie Bridge- underCambie BridgeFraser river walkwayFraser river walkwayFraser river walkwayFraser River ParkFraser River TrailFraser River pathwayAquatic centreBeach CrescentPacific StPacific BlvdCreekside ParkSouth Lost LagoonSouth Lost LagoonHastings ParkHastings ParkOff BridgewayHastings ParkHastings ParkHastings ParkGladstoneL/S of  E 13th AveE 
# ...

# %%
data_file.plot()

# %%
gpd.read_file('city.shp').plot()

# %%
data_file.plot()
